# %% [markdown]
# ## Ficha del Problema: Desplazamiento del Repartidor
# ### Parte A: Completar la ficha del problema
# * **Estado inicial:** `"Almacen"`
# * **Estado objetivo:** `"ZonaNorte"
# * **Acciones posibles:**
#   * Desplazarse entre los puntos interconectados de la ciudad: *Almacén, Centro, Terminal, Mercado y Zona Norte* según las rutas disponibles en el mapa vial.
# * **Costo de cada acción:**
#   * 1 paso o unidad de distancia por cada tramo o arista recorrida entre un punto de la ciudad y el siguiente.
# * **Solución (Secuencia de acciones esperada):**
#   * `Almacen` $\rightarrow$ `Centro` $\rightarrow$ `ZonaNorte` (o rutas alternativas equivalentes según el algoritmo de búsqueda).

# %% [markdown]
# ### Parte B: Representación del mapa de la ciudad como un grafo

# %%
mapa = {
    "Almacen": ["Centro", "Terminal"],
    "Centro": ["Almacen", "ZonaNorte", "Mercado"],
    "Terminal": ["Almacen", "Mercado"],
    "Mercado": ["Centro", "Terminal", "ZonaNorte"],
    "ZonaNorte": ["Centro", "Mercado"],
}
print(mapa)
# Out:
# {'Almacen': ['Centro', 'Terminal'], 'Centro': ['Almacen', 'ZonaNorte', 'Mercado'], 'Terminal': ['Almacen', 'Mercado'], 'Mercado': ['Centro', 'Terminal', 'ZonaNorte'], 'ZonaNorte': ['Centro', 'Mercado']}

# %% [markdown]
# #### Explicacion de Creación del mapa
#
# Este bloque crea un **mapa de conexiones** entre diferentes lugares.
#
# - `mapa = {}`: Crea un diccionario para almacenar los lugares y sus conexiones.
# - `"Almacen"`: Indica que está conectado con **Centro** y **Terminal**.
# - `"Centro"`: Indica que está conectado con **Almacen, ZonaNorte y Mercado**.
# - `"Terminal"`: Indica que está conectado con **Almacen y Mercado**.
# - `"Mercado"`: Indica que está conectado con **Centro, Terminal y ZonaNorte**.
# - `"ZonaNorte"`: Indica que está conectado con **Centro y Mercado**.
# - `print(mapa)`: Muestra el mapa completo en pantalla.
#
# **Resultado:** Se obtiene un mapa donde cada lugar tiene registrados los lugares a los que está conectado.

# %% [markdown]
# ### Implementacion de DFS

# %%
def dfs(grafo, inicio, objetivo):
    """Busca un camino entre 'inicio' y 'objetivo' usando DFS."""
    pila = [[inicio]]
    visitados = set()
    while pila:
        camino = pila.pop()  # sacar el ULTIMO camino de la pila (LIFO)
        nodo_actual = camino[-1]
        if nodo_actual == objetivo:
            return camino
        if nodo_actual not in visitados:
            visitados.add(nodo_actual)
            for vecino in grafo[nodo_actual]:
                # COMPLETAR: misma logica que en BFS, pero agregando a la pila
                nuevo_camino = camino + [vecino]
                pila.append(nuevo_camino)
    return None

resultado_dfs = dfs(mapa, "Almacen", "ZonaNorte")
print("Camino encontrado (DFS):", resultado_dfs)
# Out:
# Camino encontrado (DFS): ['Almacen', 'Terminal', 'Mercado', 'ZonaNorte']

# %% [markdown]
# #### Explicacion de Búsqueda DFS
#
# Este bloque de código utiliza el algoritmo **DFS (búsqueda en profundidad)** para encontrar un camino entre dos lugares del mapa.
#
# - `def dfs(...)`: Crea la función que realizará la búsqueda DFS.
# - `pila`: Guarda los caminos que se van encontrando durante la búsqueda.
# - `visitados`: Registra los lugares que ya fueron revisados.
# - `while pila`: Continúa la búsqueda mientras existan caminos disponibles.
# - `camino.pop()`: Toma el último camino de la pila, siguiendo la lógica **LIFO**.
# - `nodo_actual`: Obtiene el lugar en el que se encuentra actualmente.
# - `if nodo_actual == objetivo`: Comprueba si se llegó al destino.
# - `for vecino`: Revisa los lugares conectados al lugar actual.
# - `nuevo_camino`: Crea un camino agregando el siguiente lugar.
# - `pila.append()`: Agrega el nuevo camino a la pila.
# - `resultado_dfs`: Ejecuta la búsqueda desde `Almacen` hasta `ZonaNorte`.
# - `print()`: Muestra el camino encontrado.

# %% [markdown]
# ### vectores y matrices con NumPy

# %%
import numpy as np

# Parte A: Representación de cuatro observaciones (temperatura y humedad)
obs1 = np.array([22.5, 60])  # temperatura, humedad
obs2 = np.array([19.0, 45])
obs3 = np.array([25.3, 70])
obs4 = np.array([21.0, 50])

dataset = np.array([obs1, obs2, obs3, obs4])
print("Dataset completo:\n", dataset)
print("Forma de la matriz (filas, columnas):", dataset.shape)

# Parte B: Acceso a filas y columnas específicas
print("Primera observacion (fila 0):", dataset[0])
print("Todas las temperaturas (columna 0):", dataset[:, 0])
# Out:
# Dataset completo:
#  [[22.5 60. ]
#  [19.  45. ]
#  [25.3 70. ]
#  [21.  50. ]]
# Forma de la matriz (filas, columnas): (4, 2)
# Primera observacion (fila 0): [22.5 60. ]
# Todas las temperaturas (columna 0): [22.5 19.  25.3 21. ]

# %% [markdown]
# #### Explicacion de Representación de datos con NumPy
#
# Este bloque utiliza **NumPy** para crear y organizar datos de temperatura y humedad en una matriz.
#
# - `import numpy as np`: Importa NumPy para trabajar con arreglos y matrices.
# - `obs1`, `obs2`, `obs3`, `obs4`: Representan cuatro observaciones de temperatura y humedad.
# - `dataset`: Une las cuatro observaciones en una sola matriz.
# - `print("Dataset completo...")`: Muestra todos los datos almacenados.
# - `dataset.shape`: Muestra el tamaño de la matriz, indicando filas y columnas.
# - `dataset[0]`: Muestra la primera observación.
# - `dataset[:, 0]`: Obtiene todas las temperaturas, que corresponden a la primera columna.
#
# **Resultado:** Se crea una matriz con **4 observaciones y 2 características: temperatura y humedad**.

# %% [markdown]
# ### Producto escalar y distancia euclidiana

# %%
# Parte A: Calcular el producto escalar entre dos observaciones
producto = np.dot(obs1, obs2)
print("Producto escalar entre obs1 y obs2:", producto)

# Parte B: Calcular la distancia euclidiana entre dos observaciones
# 1. Fórmula manual
distancia_manual = np.sqrt(np.sum((obs1 - obs2) ** 2))
print("Distancia manual:", distancia_manual)

# 2. Con la función integrada de NumPy
distancia_numpy = np.linalg.norm(obs1 - obs2)
print("Distancia con NumPy:", distancia_numpy)
# Out:
# Producto escalar entre obs1 y obs2: 3127.5
# Distancia manual: 15.402921800749363
# Distancia con NumPy: 15.402921800749363

# %% [markdown]
# #### Explicacion de Producto escalar y distancia euclidiana
#
# Este bloque realiza cálculos matemáticos entre dos observaciones usando **NumPy**.
#
# - `np.dot(obs1, obs2)`: Calcula el **producto escalar** entre las dos observaciones.
# - `producto`: Guarda el resultado del producto escalar.
# - `np.sqrt(np.sum((obs1 - obs2) ** 2))`: Calcula manualmente la **distancia euclidiana** entre las observaciones.
# - `np.linalg.norm(obs1 - obs2)`: Calcula la misma distancia euclidiana usando una función de NumPy.
# - `print(...)`: Muestra los resultados de los cálculos.
#
# **Resultado:** Se obtiene el producto escalar y la distancia entre `obs1` y `obs2`, comprobando que ambas formas de calcular la distancia dan el mismo resultado.

# %% [markdown]
# ## 5. Ejercicio Práctico de Laboratorio

# %% [markdown]
# ### Mapa de la ciudad

# %%
import numpy as np

# Mapa de la ciudad en forma de grafo (Sección 4.2 / 5.2)
mapa = {
    "Almacen": ["Centro", "Terminal"],
    "Centro": ["Almacen", "ZonaNorte", "Mercado"],
    "Terminal": ["Almacen", "Mercado"],
    "Mercado": ["Centro", "Terminal", "ZonaNorte"],
    "ZonaNorte": ["Centro", "Mercado"],
}

# %% [markdown]
# #### Explicación del mapa como grafo
#
# Este bloque representa un **mapa de la ciudad mediante un grafo**, usando un diccionario de Python.
#
# - `mapa`: Guarda los lugares y sus conexiones.
# - `"Almacen": ["Centro", "Terminal"]`: Indica que Almacén está conectado con Centro y Terminal.
# - Cada lugar representa un **nodo** y cada conexión representa una **ruta o arista**.
# - Esta estructura permite representar y analizar las **rutas entre diferentes lugares de la ciudad**.

# %% [markdown]
# ### Dataset de observaciones de temperatura y humedad

# %%
obs1 = np.array([22.5, 60])
obs2 = np.array([19.0, 45])
obs3 = np.array([25.3, 70])
obs4 = np.array([21.0, 50])

dataset = np.array([obs1, obs2, obs3, obs4])

# %% [markdown]
# #### Explicación del dataset de temperatura y humedad
#
# Este bloque representa un **conjunto de observaciones de temperatura y humedad**, usando arreglos de NumPy.
#
# - `obs1`, `obs2`, `obs3` y `obs4`: Guardan cada observación.
# - Cada observación contiene **temperatura y humedad**.
# - `dataset`: Junta todas las observaciones en un solo arreglo.
# - Cada fila representa una **medición diferente**.
# - Esta estructura permite **organizar y analizar los datos de temperatura y humedad**.

# %% [markdown]
# ### Implemetacion del DFS

# %%
def dfs(grafo, inicio, objetivo):
    """Busca un camino entre 'inicio' y 'objetivo' usando DFS (Pila - LIFO)."""
    pila = [[inicio]]
    visitados = set()
   
    while pila:
        camino = pila.pop()  # saca el ÚLTIMO camino de la pila
        nodo_actual = camino[-1]
       
        if nodo_actual == objetivo:
            return camino
           
        if nodo_actual not in visitados:
            visitados.add(nodo_actual)
            for vecino in grafo[nodo_actual]:
                nuevo_camino = camino + [vecino]
                pila.append(nuevo_camino)
               
    return None

resultado_dfs = dfs(mapa, "Almacen", "ZonaNorte")
print("Camino encontrado (DFS):", resultado_dfs)
# Out:
# Camino encontrado (DFS): ['Almacen', 'Terminal', 'Mercado', 'ZonaNorte']

# %% [markdown]
# #### Explicación del algoritmo DFS
#
# Este bloque implementa una **búsqueda en profundidad (DFS)** para encontrar un camino entre dos lugares del grafo.
#
# - `dfs`: Busca un camino desde el nodo inicial hasta el objetivo.
# - `pila`: Guarda los caminos pendientes de explorar y funciona con **LIFO**.
# - `visitados`: Guarda los nodos que ya fueron recorridos.
# - `pila.pop()`: Toma el último camino agregado para continuar la búsqueda.
# - `resultado_dfs`: Guarda el camino encontrado desde `"Almacen"` hasta `"ZonaNorte"`.
# - `print`: Muestra el camino encontrado por el algoritmo.
